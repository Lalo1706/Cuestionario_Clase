# %% [markdown]
# Estructura de datos 1310
# La funcion "Print"
#
# 1. Utilizando "+"
# 2. Utilizando comillas dobles o simples
# 3. Utilizando funcion format
# 4. Operador f'
# 5. Utilizando una coma ","

# %%
nombre = "Eduardo"
carrera = "Ingenieria en computacion"

print("Hola ", nombre +  " Hola")
print("Tu nombre es ", nombre, "y estudiaste", carrera)

#Con format
print("Tu nombre es {0} y estudiaste {1}".format("Armando", carrera))

#Con el operador f"""
print(f"Tu nombre es {nombre} y estudiaste {carrera}")

#Salto de linea
print(nombre, end = "")
print(" ", end = "")
print(carrera, end = "")

# %% [markdown]
# Entrada de datos
#
# funcion input()
# Sirve para pedir datos al usuario, equivalentemente a scanf en leng "C" o a clase de Scanner de Java siempre regresa un String.

# %%
nombre = input("Introduce tu nombre, amigo ")
print(nombre)

semestre = input("En que semestre estas ")
print(semestre)
semestre = int(input(semestre)) +1
print(semestre)

semestre = int(input("Cual es tu semestre "))
int(input(semestre)) +1

# %% [markdown]
# Repaso del tipo de dato String.
#
# Es un tipo de dato muy versatil. Los tipos de dato en Python, en realidad son objetos (POO), es decir, tienen atributos y metodos.
#
# Los valores internos de un String se almacenan como un arreglo.
#
# Es decir, se accede a los elementos con el operador [Indice]

# %%
frase = "El conocimiento me persigue... Pero yo soy mas rapido!!+"

#Como se almacena la informacion

print(frase[3])

print(len(frase))

print(frase[55])

#Indexado negativo
print(frase[-8])

#Iterar sobre un string
for letra in frase:
    print(letra)
print("FIN")

# %% [markdown]
# Slincing (Rebanado)
#
# Es posible seleccionar segmentos de una lista (str) por medio de la sintaxis [::]
# Por defecto:
#
# * Inicio = 0, -1
# * Tope = tamaño de la lista (str), no incluye el tope, se queda uno antes, -0
# * Incremento =1,-1

# %%
nombre = "Facultad de Estudios Superiores Aragon"

print (nombre[0])
print (nombre[-1])

#Slicing
print (nombre[ 2:5:1])
print (nombre[0 : 8: 1])

#Slicing con indexado negativo (-)
print (nombre[ -6: 0:1])

print (nombre[ 7: :-1])

# %% [markdown]
# String como objeto
#
# El tipo de dato string es una clase, por lo tanto tiene atributos y metodos
#
# Ayuda en linea Python
#
# Hay dos funciones que te seran de ayuda en python
#
# 1. dir()
# 2. help()

# %%
dir(str)

# %%
apellidos = "galicia orozco"

print( apellidos.capitalize() )
print( apellidos.title() )
print( apellidos.find('a') )
print( "LOPEZ PEREZ".lower() )
print( apellidos.upper() )

numero= "   1,     2,   3,  4,5,6   "
num_dividos = numero.strip().split('.')
print( num_dividos)

#num_dividos[0] = num_dividos[0].strip()
#num_dividos[1] = num_dividos[1].strip()
#num_dividos[2] = num_dividos[2].strip()
#num_dividos[3] = num_dividos[3].strip()
#num_dividos[4] = num_dividos[4].strip()
#num_dividos[5] = num_dividos[5].strip()

print(num_dividos)

for eles in num_dividos:
    print(eles)

for index in range(5):
    num_dividos[index] = num_dividos[index].strip()

print(num_dividos)

# %% [markdown]
# Estrucutra de control
#
# if
#
# if else
#
# switch - case (En python se implementa con if)
#
# for
#
# while y do-while

# %%
#if

a = 12
b = 23
c = 4
print( a > b)

if a > b :
    print("Estamos en el IF ")
    print("A es mayor que B ")
print("Fin del programa")


################
if c > a:
    if c > b:
        print ("C es el mayor de los tres ")

if c > a and c > b:
    print("C es el mayor de los tres")

#if-else, cuál de las tres variables es mayor
if a > b:
    if a > c:
        print("A es la mayor ")
    else: 
        print("C es la mayor ")
else: 
    if b > c:
        print("B es la mayor")
    else: 
        print("C es la mayor")

#if-else (elif) tiene una notacion especial, cuando se encadena un if dentro de un else
if a > b:
    if a > c:
        print("A es la mayor ")
    else: 
        print("C es la mayor ")
elif b > c:
        print("B es la mayor")
else: 
        print("C es la mayor")

#Pedir a un usuario un numero entre 1  a 7, e imprimir el día de semana que corresponda
opcion = int(input("Introduce un número entre 1 y 7 "))

if opcion > 0 and opcion < 8:
    if opcion == 1:
        print("Lunes ")
    elif opcion == 2:
        print("Martes ")
    elif opcion == 3:
        print("Miercoles ")
    elif opcion == 4:
        print("Jueves ")
    elif opcion == 5:
        print("Viernes ")
    elif opcion == 6:
        print("Sabado ")
    elif opcion == 7:
        print("Domingo ")

else: 
    print("Tu dato está fuera de lo solicitado ")

# %% [markdown]
# Funciones
#
# Es un segmento de código que recibe cero o mas valores de entrada, realiza una o un conjuto de operaciones de forma interna y regresa un solo tipo de dato, aunque sea de valor none (Void)
#
# Las funciones se declaran con la palabra def.

# %%
#Funcion suma

def suma (a, b):
    c = 0
    c = a + b
    return c

print(suma(4, 5))

#Funcion que salude personas

def saludar (nombre):
    print(f"Hola {nombre}, ¿Como estas")

saludar("Lalo")
nombre = "Galicia"
saludar(nombre)

res= saludar(nombre)
print(res)

# %% [markdown]
# # Tuplas
#
# * Estructura de dato lineal
# * Se declaran con (  )
# * Son **inmutables**
# * Usan menos espacio en memoria
# * Son utiles para declarar valores de consulta
# * Fuera de eso, las demas caracteristicas son las mismas que las LISTAS.

# %%
datos_conexion = ("123.234.345.145.23", "lalo", "galicia17")
print( datos_conexion[0])

# %% [markdown]
# Default y funciones
#
# Hay ocasiones que es necesario declarar valores por defecto en los argumentos de una funcion

# %%
def saludar(nombre, veces):
    for x in range(veces):
        print(f"Hola {nombre} ")
saludar("Lalo", 2)


def saludar(nombre, veces=5 ):
    for x in range(veces):
        print(f"{x} .- Hola {nombre} ")
saludar("Lalo", 3)
# Out:
# Hola Lalo
# Hola Lalo
# 0 .- Hola Lalo
# 1 .- Hola Lalo
# 2 .- Hola Lalo

# %% [markdown]
# Diccionarios.
#
# * Estructura no lineal
# * Formada por pares llave - valor
# {"Key":valor}
#
# Donde valor puede ser de cualquier tipo, int , float, list, diccionario.
#
# * NO se selecciona con [ ] X
#
# Su selector es por llave (key)
#
#
# Son mutables.

# %%
estudiante = {
"nombre" : { "nombres" : ["Juan", "Jose"] ,
"paterno" : "Pérez" ,
"materno" : " Garcia"
},
"edad" : 19 ,
"estatura" : 1.7,
"carrera" : {
"escuela" : "UNAM FES Aragón",
"Carrera" : "ICO",
"semestre" : 2
},
"direccion" : {
"calle" : "Colorines",
"num_exterior" : 34,
"interior" : "apartmento B"
},
"telefonos" : {
"casa" : 556463663,
"celular" : ["+5255767664" , "+52557373773"]
}

}


# ejemplo
print(estudiante['direccion']['calle'])
print(f"La estatura es : {estudiante['estatura']}")
print( estudiante['telefonos']['celular'][1])
estudiante['direccion']['calle'] = 'Pancho Lopez'
print(estudiante['direccion'])
estudiante['direccion']['colonia'] = 'Impulsora'
print(estudiante['direccion'])

#combinar con la invocacion de metodos de los valores.
#Mostrar el nombre del estudiante en MAYUSCULAS.

print(estudiante['nombre']['nombres'][0].upper(), estudiante['nombre']['nombres'][1].upper())

#Keys()
llaves = estudiante.keys()
print(llaves)
print("-----------------------------------------")
for llave in llaves:
    print(llave)
    print(estudiante[llave])
print("---------------------------------------------")
#values()
vals = estudiante.values()
for val in vals:
    print(val)


print("--------------------- items --------------------------")
elems = estudiante.items()
print(elems)

for par in elems:
    #print(par)
    print(par[1])

#Fin de la intro de diccionarios

# %% [markdown]
# # Funciones 2a parte (El reencuentro)
#
# ### Declarar funciones combinandola con **tuplas**
# Se puede recibir una lista de argumentos dinamica que se almacenará en una tupla. Para ello se utiliza un operador especial que es '*' en la declaracion de la funcion.
#
# def mi_funcion(  *algo): print (algo)

# %%
def mi_funcion( *argumentos):
    print(argumentos)

mi_funcion(1, 2, 3, "Hola", 3.1416)

# %% [markdown]
# # Modulos
#
# Un modulo en python es una equivalente a un package n java o un archivo .H en lenguaje C.
#
# En él, declaras el codigo que quieras llamar varias veces, este codigo debe estar empaquetado principalmente en funciones

# %%
import Mimodulo

Mimodulo.mi_suma (3, 4)

Mimodulo.mi_print ("Hola como estas")
Mimodulo.al_reves ("Hola como estas")

# %%
from Mimodulo import mi_print

mi_print ("Nueva forma simplificada")

# %%
from Mimodulo import  al_reves

al_reves ("Nueva forma simplificada")

# %%
from Mimodulo import mi_suma

mi_suma (10, 4)

# %%
# !pip install simple-chalk

# %%
from simple_chalk import *
print(chalk.green("Texto en verde"))

whynot = green.bgWhite.yellow.bgGray
print(whynot("Kombanwa watashi wa Eduardo desu"))

pruebados = bgWhite.red
print(pruebados("Camote") )

# %% [markdown]
# * Archivos
#
# Para abrir un archivo se utiliza la funcion open ('Nombre', 'AB')
#
# nombre = la ruta del archivo
#
# A= modo de apertura
#
# B= Formato (Texto(t) o Binario (b))
#
# Para leer tenemos las funciones:
#
# - read ()
# - redline ()
# - readlines ()

# %%
# !cat Datos.dat
# Out:
# cat: Datos.dat: No such file or directory

# %%
"""
1, 2, 3, 5, 6, 7
8, 9, 10
11, 12
13
"""
archivo = open('Datos.dat', 'rt')
info = archivo.read()
print(info)

#ReadLine()
print("----- READLINE -----")
archivo = open('Datos.dat', 'rt')
info = archivo.readline() 
print(info)          #Se coloca la misma info para seleccionar otra linea
info = archivo.readline()
print(info)

#ReadLines()
print("----- READLINES -----")
archivo = open('Datos.dat', 'rt')
info = archivo.readlines()
print(info)
for index in range (len(info)):
    info[index] = info[index].strip()

print(info)

numeros = []

for grupo in info:
    for numero in grupo.split(','):
        numeros.append(int(numero))
print(numeros)

suma = 0
for num in numeros:
    suma += num
print(suma)

# %% [markdown]
# # Programacion Orientada a Objetos (Python)
#
# La POO es un paradigma no soportado originalmente por Python, python maneja el paradiga imperativo.
#
# Python simula la POO con la declaracion de clases y haciendo referencia a un objeto de forma circular. **self en python es equivalente a this de java**
#
# 1. Forma 1.
#
# class <nombre de la clase>:
#         <definicion de la clase>
#
# 2. Forma 2.
#
#
# class <nombew de la clase > {<super class>):
#         <Definicion del cuerpo de la clase>
#
#
# El constructor se define siempre con el metodo __init__:() (DOBLE GUION BAJO ANTES Y DESPUES DEL "INIT")
#
# La declaracion de atributos se realiza por medio de el constructor.
#
#
# Para hacer encapsulamiento de metodos o atributos se debe porner __(DOBLE GUION BAJO) previo a la declaracion de atributo o metodo.

# %%
class persona:                 #SELF en Python es equivalente a this de java
    def __init__( self, n, e, est ):   
        self.__nombre = n
        self.__edad = e
        self.__estatura = est
    
    def to_string( self ):
        return "Nombre: " + self.__nombre + " Edad: " + str(self.__edad) + " Estatura: " + str(self.__estatura)

    def set_estatura( self, nueva_est):
        if nueva_est > 0.10 and nueva_est < 2.5 :
            self.__estatura = nueva_est
        else:
            print("Erro, esta estatura no es posible")

    def get_estatura(self):
        return self.__estatura

# %%
per = persona("Jose", 19, 1.7)
print(per.to_string())

#Encapsulamiento 

per.nombre ="Pedro"    #ESTO NO SE RECOMIENDA
print(per.to_string())

#per.estatura = 3.9
per.set_estatura(1.9)
print(per.to_string())

print("Estatura: ", end="" )
#print(per._persona__estatura)
print(per.get_estatura())
# Out:
# Nombre: Jose Edad: 19 Estatura: 1.7
# Nombre: Jose Edad: 19 Estatura: 1.7
# Nombre: Jose Edad: 19 Estatura: 1.9
# Estatura: 1.9

# %%
class Estudiante( persona ):
    def __init__(self, nc, nombre, edad, est):
        self.__num_cta = nc
        super().__init__(nombre, edad, est)

    
    def to_string( self ):
        return str(super().get_estatura()) + " Numero de cuenta: " + self.__num_cta

# %%
est = Estudiante(  "212020202", "Jose", 18, 1.7 )
print( est.to_string())
# Out:
# 1.7 Numero de cuenta: 212020202
